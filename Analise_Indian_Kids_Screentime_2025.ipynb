# %% [markdown]
# <a href="https://colab.research.google.com/github/ItaloElias/Colab_Analise_Tempo_de_tela/blob/main/Analise_Indian_Kids_Screentime_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Análise do Tempo de Tela de Crianças Indianas (2025)
#
# **Um estudo sobre hábitos digitais e impactos na saúde infantil**
#
# _Dados baseados em pesquisa realizada entre 2023 e 2024_
#
# <br>
#
# ---
#
# **Curso de Python para Análise de Dados - SENAI**
#
# **Autor:** Italo Elias | **Data:** Agosto 2025
#
#
# ---
#
# ## 🧒 Sobre o Conjunto de Dados
#
# Este conjunto simula os padrões de tempo de tela de **9.712 crianças indianas**, entre **8 e 18 anos**, em contextos **urbanos e rurais**. Com base em estudos de **2023 e 2024**, ele reflete:
#
# - Diferenças no uso de telas por idade, gênero e localidade;
# - Possíveis impactos na saúde física e mental.
#
# ---

# %% [markdown]
# ### 📁 Estrutura dos Dados
#
# As variáveis incluídas permitem análises sob diferentes perspectivas, como:
#
# - Idade das crianças;
# - Tempo total de uso;
# - Se o uso excede as diretrizes da **Academia Indiana de Pediatria (IAP)**;
# - Efeitos na saúde, como:
#   - 💤 Qualidade do sono
#   - 👀 Fadiga ocular
#   - 😟 Ansiedade
#   - ⚖️ Risco de obesidade
#
# ---

# %% [markdown]
# ## 🎯 Contexto e Motivação
#
# A análise do tempo de tela entre crianças e adolescentes se tornou essencial no cenário pós-pandemia. Este estudo busca compreender padrões de uso e seus impactos com base nos seguintes pontos:
#
# ### 1️⃣ Aumento do uso após a COVID-19
#
# ### 2️⃣ Uso acima do recomendado
#
# ### 3️⃣ Impactos na saúde
#
# ### 4️⃣ Importância dos dados
#
# ---

# %% [markdown]
# ## 🔍 O que será analisado
#
# > A seguir, exploraremos os dados com foco em:
#
# - 🩺 Impactos do tempo de tela na saúde infantil
# - ⏱️ Proporção que excede o limite recomendado
# - 📈 Relação entre idade e tempo de tela
# - 🌆 Diferenças entre áreas urbanas e rurais
# - 📊 Distribuição geral do tempo de tela
#
# ---
#
# > 🔗 **Fonte dos dados:** [Kaggle – Indian Kids Screentime 2025](https://www.kaggle.com/datasets/ankushpanday2/indian-kids-screentime-2025)

# %% [markdown]
# ## Distribuição do Tempo de Tela Diário (horas)
#
# - Tempo de tela varia entre as crianças analisadas
# - Concentração maior em torno de determinadas faixas horárias
# - Identificação de padrões comuns e casos com uso excessivo
# - Reforça a importância do monitoramento conforme recomendações médicas

# %% [markdown]
# <img src="data:image/png;base64,..." alt="Imagem crianças" width="1100"/>

# %% [markdown]
# ## Distribuição do Tempo de Tela por Área
#
# - Crianças da área urbana passam mais horas em frente às telas
# - Uso reduzido observado em áreas rurais
# - Diferenças refletem acesso e hábitos distintos
# - Importância de considerar contexto regional para estratégias de controle

# %% [markdown]
# <img src="data:image/png;base64,..." alt="Imagem crianças" width="1100"/>

# %% [markdown]
# ## Dispersão de Idade por Tempo de Tela Diário
#
# - Uso de tela mais alto entre crianças de 8 a 10 anos
# - Entre 11 e 18 anos, o tempo se mantém alto, mas mais concentrado entre 2 e 7 horas diárias
# - Indica mudança no padrão de uso com a idade, embora o uso continue significativo
# - Relevante para orientar intervenções específicas por faixa etária

# %% [markdown]
# <img src="data:image/png;base64,..." alt="Imagem crianças" width="1100"/>

# %% [markdown]
# ## Proporção que Excede o Limite Recomendado
#
# - 91,4% das crianças excedem o limite de tempo de tela recomendado
# - Indica uso excessivo generalizado
# - Alerta para possíveis impactos negativos na saúde
# - Reforça a necessidade de políticas e orientações claras

# %% [markdown]
# <img src="data:image/png;base64,..." alt="Imagem crianças" width="1100"/>

# %% [markdown]
# ## Principais Impactos na Saúde
#
# - Impacto no sono é o mais frequente
# - Ansiedade, obesidade e cansaço visual também apresentam alta incidência
# - Sinaliza múltiplos efeitos negativos associados ao uso excessivo de telas

# %% [markdown]
# <img src="data:image/png;base64,..." alt="Imagem crianças" width="1100"/>

# %% [markdown]
# ## Conclusão
#
# - A maioria das crianças excede o tempo de tela recomendado
# - Uso maior em áreas urbanas
# - Tempo de tela alto em todas as idades, especialmente 8-10 anos
# - Problemas de sono e saúde são frequentes
# - Necessário monitorar e orientar o uso de telas

# %% [markdown]
# <img src="https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEiLpKnY55bcdaE7IpsKW406zvcE93NCjCs5grhuJtsDIhZlXjDaJ0x_E8K1HxlD6B5dup6Ih8RIiW_iFxhSAJsqJhOOLvuKlBI2w09HzPJHl1A2sILii50NhjicRN6q7Wb5xn55JPVap32-rZRagG-slkShPWfKy11O6N94OLXQz60a1mFeeBmhcQ69/s1647/crianca.jpg" alt="Imagem crianças" width="1100"/>

# %%
# importações

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Configuração do seaborn
sns.set(style="whitegrid")

# Carregar os dados

df = pd.read_csv("Indian_Kids_Screen_Time.csv")

# Tipos de dados das colunas
tipos_dados = df.dtypes

# %%
# tratando titulos
df.columns = [
    "Idade",
    "Gênero",
    "Tempo Médio de Tela (h/dia)",
    "Dispositivo Principal",
    "Excedeu Limite Recomendado",
    "Relação Educacional/Recreativo",
    "Impactos na Saúde",
    "Área (Urbana ou Rural)"
]

# --- Coluna saude ---

traducao = {
    "Poor Sleep": "Sono Ruim",
    "Eye Strain": "Cansaço Visual",
    "Anxiety": "Ansiedade",
    "Obesity Risk": "Risco de Obesidade"
}

df['Impactos na Saúde'] = df['Impactos na Saúde'].dropna().apply(
    lambda x: ', '.join([traducao.get(i.strip(), i) for i in x.split(',')])
)

# %%
print(df.columns)
print(df.head())
# Out:
# Index(['Idade', 'Gênero', 'Tempo Médio de Tela (h/dia)',
#        'Dispositivo Principal', 'Excedeu Limite Recomendado',
#        'Relação Educacional/Recreativo', 'Impactos na Saúde',
#        'Área (Urbana ou Rural)'],
#       dtype='object')
#    Idade  Gênero  Tempo Médio de Tela (h/dia) Dispositivo Principal  \
# 0     14    Male                         3.99            Smartphone
# 1     11  Female                         4.61                Laptop
# 2     18  Female                         3.73                    TV
# 3     15  Female                         1.21                Laptop
# 4     12  Female                         5.89            Smartphone
#
#    Excedeu Limite Recomendado  Relação Educacional/Recreativo  \
# 0                        True                            0.42
# 1                        True                            0.30
# 2                        True                            0.32
# 3                       False                            0.39
# ...

# %%
# Medidas de tendência central
print("\nMédia:\n", df[['Idade', 'Tempo Médio de Tela (h/dia)', 'Relação Educacional/Recreativo']].mean())
print("\nMediana:\n", df[['Idade', 'Tempo Médio de Tela (h/dia)', 'Relação Educacional/Recreativo']].median())
print("\nModa:\n", df.mode().iloc[0][['Idade', 'Tempo Médio de Tela (h/dia)', 'Relação Educacional/Recreativo']])

# Medidas de dispersão
print("\nVariância:\n", df[['Idade', 'Tempo Médio de Tela (h/dia)', 'Relação Educacional/Recreativo']].var())
print("\nDesvio Padrão:\n", df[['Idade', 'Tempo Médio de Tela (h/dia)', 'Relação Educacional/Recreativo']].std())
print("\nAmplitude:\n", df[['Idade', 'Tempo Médio de Tela (h/dia)', 'Relação Educacional/Recreativo']].max() - df[['Idade', 'Tempo Médio de Tela (h/dia)', 'Relação Educacional/Recreativo']].min())
# Out:
# Média:
#  Idade                             12.979201
# Tempo Médio de Tela (h/dia)        4.352837
# Relação Educacional/Recreativo     0.427226
# dtype: float64
#
# Mediana:
#  Idade                             13.00
# Tempo Médio de Tela (h/dia)        4.44
# Relação Educacional/Recreativo     0.43
# dtype: float64
#
# Moda:
#  Idade                               17
# Tempo Médio de Tela (h/dia)        0.0
# Relação Educacional/Recreativo    0.45
# Name: 0, dtype: object
#
# Variância:
#  Idade                             10.001009
# Tempo Médio de Tela (h/dia)        2.952323
# Relação Educacional/Recreativo     0.005361
# dtype: float64
#
# Desvio Padrão:
#  Idade                             3.162437
# Tempo Médio de Tela (h/dia)       1.718232
# Relação Educacional/Recreativo    0.073221
# dtype: float64
#
# Amplitude:
#  Idade                             10.00
# Tempo Médio de Tela (h/dia)       13.89
# Relação Educacional/Recreativo     0.30
# dtype: float64

# %%
# Histograma distribuição de tempo de tela
plt.style.use("seaborn-v0_8")
plt.figure(figsize=(9,5),facecolor='#e8eef1')
plt.hist(df['Tempo Médio de Tela (h/dia)'], bins=15, color='steelblue', edgecolor='white', alpha=0.9)

plt.title('Distribuição do tempo de tela diário (horas)', fontsize=16, fontweight='bold')
plt.xlabel('Horas por dia', fontsize=13)
plt.ylabel('Número de crianças', fontsize=13)

plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.box(False)
plt.show()

# %%
# Histograma: média de tempo de tela por área urbana/rural
plt.style.use("seaborn-v0_8")
plt.figure(figsize=(9,5), facecolor='#e8eef1')

plt.hist(df[df['Área (Urbana ou Rural)']=='Urban']['Tempo Médio de Tela (h/dia)'],
         bins=12, color='steelblue', edgecolor='white', alpha=0.7, label='Urbano')
plt.hist(df[df['Área (Urbana ou Rural)']=='Rural']['Tempo Médio de Tela (h/dia)'],
         bins=12, color='lightgreen', edgecolor='white', alpha=0.7, label='Rural')

plt.title('Distribuição de tempo de tela por área', fontsize=16, fontweight='bold')
plt.xlabel('Horas por dia', fontsize=13)
plt.ylabel('Número de crianças', fontsize=13)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.legend()
plt.box(False)

plt.show()

# %%
# Gráfico de dispersão: relação entre idade e tempo de tela
plt.style.use("seaborn-v0_8")
plt.figure(figsize=(11,4),facecolor='#e8eef1')

sns.scatterplot(
    x='Tempo Médio de Tela (h/dia)',
    y='Idade',
    data=df,
    color='steelblue',
    s=60,
    alpha=0.8
)

plt.title('Dispersão de idade por tempo de tela diário', fontsize=16, fontweight='bold')
plt.xlabel('Horas de tela por dia', fontsize=13)
plt.ylabel('Idade', fontsize=13)

max_horas = int(df['Tempo Médio de Tela (h/dia)'].max()) + 1
plt.xticks(range(0, max_horas+1, 1))

min_idade = int(df['Idade'].min())
max_idade = int(df['Idade'].max()) + 1
plt.yticks(range(min_idade, max_idade, 1))
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.box(False)

plt.show()

# %%
# Gráfico de pizza: proporção que excede o limite recomendado

limite = 2
excede = df['Tempo Médio de Tela (h/dia)'] > limite
counts = excede.value_counts()
counts = counts.reindex([False, True])

plt.style.use("seaborn-v0_8")
fig, ax = plt.subplots(figsize=(5,5), facecolor='#e8eef1')

cores = ['#4C72B0', '#DD614A']

wedges, texts, autotexts = ax.pie(
    counts,
    autopct='%1.1f%%',
    colors=cores,
    startangle=90,
    wedgeprops={'edgecolor':'white'}
)

for autotext in autotexts:
    autotext.set_fontsize(12)
    autotext.set_color('white')
    autotext.set_fontweight('bold')

ax.legend(
    wedges,
    ['Dentro do limite', 'Excede o limite'],
    title="Legenda",
    loc="center left",
    bbox_to_anchor=(1, 0.5),
    fontsize=12,
    title_fontsize=13,
    frameon=True,
    facecolor='#f5f5f5'
)

fig.suptitle(
    f'Proporção de crianças que excedem {limite}h de tela por dia',
    fontsize=16,
    fontweight='bold',
    x=0.67,
    ha='center',
    y=0.95
)

plt.show()

# %%
# @title
# Grafico de barras: Principais impactos na saúde
impacts = df['Impactos na Saúde'].dropna().str.split(', ').explode()
impacts = impacts.str.strip()
impacts = impacts.replace({
    "Poor Sleep": "Sono Ruim",
    "Eye Strain": "Cansaço Visual",
    "Anxiety": "Ansiedade",
    "Obesity Risk": "Risco de Obesidade"
})

plt.style.use("seaborn-v0_8")
plt.figure(figsize=(8,5), facecolor='#e8eef1')
ax = plt.gca()
ax.set_facecolor('#e8eef1')

impacts.value_counts().plot(
    kind='bar',
    color='steelblue',
    edgecolor='white',
    alpha=0.8
)
plt.title('Principais impactos na saúde', fontsize=16, fontweight='bold')
plt.ylabel('Número de ocorrências', fontsize=13)
plt.xlabel('Impactos na saúde', fontsize=13)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.box(False)
plt.show()
